# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("melb_data.csv")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.nunique()
# Out:
# Suburb             314
# Address          13378
# Rooms                9
# Type                 3
# Price             2204
# Method               5
# SellerG            268
# Date                58
# Distance           202
# Postcode           198
# Bedroom2            12
# Bathroom             9
# Car                 11
# Landsize          1448
# BuildingArea       602
# YearBuilt          144
# CouncilArea         33
# Lattitude         6503
# Longtitude        7063
# Regionname           8
# Propertycount      311
# dtype: int64

# %%
cols_to_use = ['Suburb','Rooms','Type','Method','SellerG','Regionname','Propertycount',
               'Distance','CouncilArea','Bedroom2','Bathroom','Car','Landsize','BuildingArea','Price']
df = df[cols_to_use]
df.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 3  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 4  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance CouncilArea  Bedroom2  Bathroom  Car  Landsize  \
# 0         4019.0       2.5       Yarra       2.0       1.0  1.0     202.0
# 1         4019.0       2.5       Yarra       2.0       1.0  0.0     156.0
# 2         4019.0       2.5       Yarra       3.0       2.0  0.0     134.0
# 3         4019.0       2.5       Yarra       3.0       2.0  1.0      94.0
# 4         4019.0       2.5       Yarra       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price
# 0           NaN  1480000.0
# 1          79.0  1035000.0
# 2         150.0  1465000.0
# ...

# %%
df.shape
# Out:
# (13580, 15)

# %%
df.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# Price               0
# dtype: int64

# %%
df['Car'] = df['Car'].fillna(0)
df.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea     6450
# Price               0
# dtype: int64

# %%
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price               0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 1      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 2      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 3      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 4      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  CouncilArea_Moreland  \
# 0     151.96765  1480000.0                  0  ...                     0
# 1      79.00000  1035000.0                  0  ...                     0
# 2     150.00000  1465000.0                  0  ...                     0
# 3     151.96765   850000.0                  0  ...                     0
# 4     142.00000  1600000.0                  0  ...                     0
#
#    CouncilArea_Nillumbik  CouncilArea_Port Phillip  CouncilArea_Stonnington  \
# ...

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import Lasso

model_lasso_regressor = Lasso(alpha=50, max_iter=100, tol=0.1)
model_lasso_regressor.fit(X_train, y_train)
model_lasso_regressor.score(X_test, y_test)*100
# Out:
# C:\Users\perfect\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 527174351327868.94, tolerance: 347511914103256.6
#   model = cd_fast.enet_coordinate_descent(
# 66.35378648697848

# %%
from sklearn.linear_model import Ridge

model_ridge_regressor = Ridge(alpha=50, max_iter=100, tol=0.1)
model_ridge_regressor.fit(X_train, y_train)
model_ridge_regressor.score(X_test, y_test)*100
# Out:
# 66.44072458301122
